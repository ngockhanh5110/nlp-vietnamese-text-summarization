# %% [markdown]
# <a href="https://colab.research.google.com/github/ngockhanh5110/nlp-vietnamese-text-summarization/blob/main/notebooks/training_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Authenticate
from google.colab import auth
auth.authenticate_user()
print('Authenticated')
# Out:
# Authenticated

# %%
# !git clone 'https://github.com/ngockhanh5110/nlp-vietnamese-text-summarization.git'
# Out:
# Cloning into 'nlp-vietnamese-text-summarization'...
# remote: Enumerating objects: 98, done.
# remote: Counting objects: 100% (98/98), done.
# remote: Compressing objects: 100% (78/78), done.
# remote: Total 98 (delta 37), reused 50 (delta 16), pack-reused 0
# Unpacking objects: 100% (98/98), done.

# %%
# %cd '/content/nlp-vietnamese-text-summarization'
# Out:
# /content/nlp-vietnamese-text-summarization

# %%
# %%capture
# !bash requirements.sh

# %%
# !python3 test.py
# Out:
# 2021-02-22 08:04:18.848078: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# Downloading: 100% 557/557 [00:00<00:00, 514kB/s]
# Downloading: 100% 895k/895k [00:01<00:00, 828kB/s]
# Downloading: 100% 1.14M/1.14M [00:01<00:00, 1.06MB/s]
# Special tokens have been added in the vocabulary, make sure the associated word embedding are fine-tuned or trained.
# Downloading: 4.20kB [00:00, 3.61MB/s]
# Copying gs://kaggle-vbdi-test/nlp-text-summarization/15epochs/checkpoint-65000/config.json...
# Copying gs://kaggle-vbdi-test/nlp-text-summarization/15epochs/checkpoint-65000/optimizer.pt...
# Copying gs://kaggle-vbdi-test/nlp-text-summarization/15epochs/checkpoint-65000/scheduler.pt...
# Copying gs://kaggle-vbdi-test/nlp-text-summarization/15epochs/checkpoint-65000/pytorch_model.bin...
# Copying gs://kaggle-vbdi-test/nlp-text-summarization/15epochs/checkpoint-65000/training_args.bin...
# ...

# %%
import pickle 
from general_utils import *

with open('/content/nlp-vietnamese-text-summarization/testing/prediction.pkl', 'rb') as handle:
    pred = pickle.load(handle)
with open('/content/nlp-vietnamese-text-summarization/testing/reference.pkl', 'rb') as handle:
    ref = pickle.load(handle)
rouge_output = rouge.compute(predictions= pred, references= ref, rouge_types=["rouge1","rouge2","rougeL"])
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embedding are fine-tuned or trained.

# %%
with open('./testing/rouge.txt', 'w+') as f:
    for key,value in rouge_output.items():
        f.write(key.upper())
        f.write(' : ')
        f.write(repr(value.mid))
        f.write('\n')

# %%
test_data  = get_data_batch(path='./data/test_tokenized/*', test = True)

# %%
i = 1181
print('Prediction: ',pred[i])
print('Truth: ',ref[i])
# print('Content: ',test_data[i]['original'])
# Out:
# Prediction:  Ông xảy ra nhiều sai_phạm trong quản_lý dự_án đầu_tư xây_dựng công_trình giao_thông tại huyện An_Lão, TP Hải_Phòng đã bị kỷ_luật với hình_thức cách_chức.
# Truth:  Ông Nguyễn_Văn_Thông chính_thức bị cách_chức chủ_tịch UBND huyện An_Lão , TP Hải_Phòng sau khi bị cách chức_vụ trong Đảng là phó bí_thư huyện_uỷ .

# %%
# !gsutil -m cp -r './training/' 'gs://kaggle-vbdi-test/nlp-text-summarization/15epochs'
# Out:
# Copying file://./training/checkpoint-39000/pytorch_model.bin [Content-Type=application/octet-stream]...
# Copying file://./training/checkpoint-39000/optimizer.pt [Content-Type=application/octet-stream]...
# Copying file://./training/checkpoint-39000/training_args.bin [Content-Type=application/octet-stream]...
# Copying file://./training/checkpoint-39000/config.json [Content-Type=application/json]...
# Copying file://./training/checkpoint-39000/trainer_state.json [Content-Type=application/json]...
# Copying file://./training/checkpoint-58000/optimizer.pt [Content-Type=application/octet-stream]...
# ==> NOTE: You are uploading one or more large file(s), which would run
# significantly faster if you enable parallel composite uploads. This
# feature can be enabled by editing the
# "parallel_composite_upload_threshold" value in your .boto
# configuration file. However, note that if you do this large files will
# be uploaded as `composite objects
# ...

# %%
# !python3 train.py
# Out:
# 2021-02-21 03:11:46.627859: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# Downloading: 100% 557/557 [00:00<00:00, 506kB/s]
# Downloading: 100% 895k/895k [00:00<00:00, 1.78MB/s]
# Downloading: 100% 1.14M/1.14M [00:00<00:00, 2.23MB/s]
# Special tokens have been added in the vocabulary, make sure the associated word embedding are fine-tuned or trained.
# Downloading: 4.20kB [00:00, 4.06MB/s]
# 100% 6589/6589 [03:03<00:00, 36.00ba/s]
# 100% 1416/1416 [00:37<00:00, 37.58ba/s]
# Copying gs://kaggle-vbdi-test/training_data/checkpoint-65000/optimizer.pt...
# Copying gs://kaggle-vbdi-test/training_data/checkpoint-65000/pytorch_model.bin...
# Copying gs://kaggle-vbdi-test/training_data/checkpoint-65000/config.json...
# Copying gs://kaggle-vbdi-test/training_data/checkpoint-65000/trainer_state.json...
# Copying gs://kaggle-vbdi-test/training_data/checkpoint-65000/scheduler.pt...
# ...
